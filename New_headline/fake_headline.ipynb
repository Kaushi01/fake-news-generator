# %%
import random

Subjects= [
     "Donald Trump",
     "Narendra Modi",
     "Priyanka Chopra",
     "Salman Khan",
     "Hardik Pandya",
     "Elon Musk",
    "Narendra Modi",
    "Taylor Swift",
    "Virat Kohli",
    "Bill Gates",
    "Kylie Jenner",
    "Ranveer Singh",
    "Shah Rukh Khan",
    "Cristiano Ronaldo",
    "Kim Kardashian",
    "Drake",
    "Deepika Padukone",
    "Messi",
    "Kangana Ranaut",
    "Robert Downey Jr."
]

Activity= [
    " fell off the bed while winning an argument in my head",
    " chased by a dog for existing",
    " tried yoga, achieved paralysis",
    " is stuck in traffic again",
    " arguing with paparazzi in pajamas"
    " accidentally joined a Zoom class instead of a meeting",
    " fell asleep during their own speech",
    " bought an island on impulse after missing breakfast",
    " declared that Mondays should be illegal",
    " was spotted arguing with a mirror for 2 hours",
    " tried to cook Maggi and set off national alarms",
    " started a band called '404 Not Found'",
    " claims they can time travel using WiFi",
    " released a perfume that smells like success and confusion",
    " just admitted their pet runs their social media account"
]


Location= [
    " near metro station.",
    " near the park.",
    " at school",
    " in Jaipur.",
    " in USA."
    " in Mumbai",
    " at a secret beach",
    " near India Gate",
    " in a traffic jam on Mars",
    " inside a coffee shop for billionaires",
    " during a live interview",
    " at a mysterious party",
    " outside Parliament House",
    " in New York City",
    " while on a plane to nowhere"
]

while True:
  sub= random.choice(Subjects)
  loc= random.choice(Location)
  act= random.choice(Activity)

  print("\n", f"{sub}{act}{loc}")

  user_input= input("Do you want to print another fake headline?(Yes/No): ").strip().lower()

  if user_input=="no":
    print("\n""I hope you had fun! Goodbye buddy")
    break
# Out:
#  Salman Khan fell off the bed while winning an argument in my head in USA.
#
#  Donald Trump fell off the bed while winning an argument in my head in Jaipur.
#
#  Donald Trump fell off the bed while winning an argument in my head in Jaipur.
#
#  Salman Khan tried yoga, achieved paralysis at school
#
#  Narendra Modi tried yoga, achieved paralysis in USA.
#
#  Salman Khan is stuck in traffic again in USA.
#
#  Narendra Modi tried yoga, achieved paralysis near the park.
#
# I hope you had fun! Goodbye buddy
